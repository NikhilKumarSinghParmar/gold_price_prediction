# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snb
from datetime import datetime
import os,sys
import  joblib

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
from keras.layers import (
    Input,
    LSTM,
    Dropout,
    Dense
)
from keras.models import (
    Model,
    Sequential,
    load_model
)
from tensorflow.keras.callbacks import (
    Callback,
    TensorBoard,
    EarlyStopping
)

# %%
def locate_input_file(input_file_name="gold_price_2013_2023.csv"):
    try:
        dir_name=os.getcwd()
        input_file_path=os.path.join(dir_name,input_file_name)
        # print(input_file_path)
        # input_file_path="/content/gold_price_2013_2023.csv"
        return input_file_path

    except Exception as e:
        print(f"error : {e}")

# %%
def get_input_data(file_path):

    try:
        df=pd.read_csv(file_path)
        return df

    except Exception as e:
        print(f"error : {e}")

# %%
def print_details(df):
    try:
        print(f"shape of df : {df.shape}\n")
        print(f"columns of df : {df.columns}\n\n")
        print(f"information about df : \n{df.info()}\n\n")
        print(f"description about df : \n{df.describe()}\n\n")
        print(f"head of df : \n{df.head()}\n\n")
        print(f"tail of df : \n{df.tail()}\n\n")

        # for col in df.columns:
        #     print(f"value count of df : \n {df[col].value_counts()}")

    except Exception as e:
        print(f"error : {e}")

# %%
def remove_unwanted_columns(df,unwanted_columns):
    try:
        # unwanted_columns=['Open', 'High', 'Low', 'Vol.', 'Change %']
        unwanted_count=len(unwanted_columns)
        # print(unwanted_count)
        temp_count=0
        for col in unwanted_columns:
            if col in df.columns:
                temp_count+=1


        if temp_count==unwanted_count :
            print(f"all unwanted columns can be removed.")
        else:
            print(f"all unwanted columns can not be removed.")

        df=df.drop(columns=unwanted_columns,axis=1)

        return df

    except Exception as e:
        print(f"error : {e}")

# %%
def sort_date(df):
    try:
        df.sort_values(
            by=["Date"],
            axis=0,
            ascending=True,
            inplace=True
        )
        # print(f"first 5 data : \n{df[:5]}")
        # print(f"last 5 data : \n{df[-5:]}")
        return df

    except Exception as e:
        print(f"error : {e}")

# %%
def clean_data(df,dir_name):
    try:
        df["Date"]=pd.to_datetime(df["Date"])
        df["Price"]=df["Price"].str.replace(",","").astype(float)
        df=sort_date(df)

        scaler=MinMaxScaler()
        df["Price"]=scaler.fit_transform(df[["Price"]])

        file_dir=os.path.join(os.getcwd(),"scaler")
        file_name=f"price_MinMaxScaler_{dir_name}.pkl"
        file_path=os.path.join(file_dir,file_name)

        os.makedirs(
            file_dir,
            exist_ok=True
        )

        joblib.dump(
            scaler,
            file_path
        )

        return df

    except Exception as e:
        print(f"error : {e}")

# %%
def handle_missing(df):
    try:
        print(f"Column-wise missing values:\n{df.isnull().sum()}\n")
        print(f"Total missing values: {df.isnull().sum().sum()}\n")

        num_cols = df.select_dtypes(include=["int64", "float64"]).columns
        cat_cols = df.select_dtypes(include="object").columns

        print(f"Numerical columns: {list(num_cols)}")
        print(f"Categorical columns: {list(cat_cols)}")

        # Fill missing values
        for col in num_cols:
            df[col] = df[col].fillna(df[col].mean())

        for col in cat_cols:
            df[col] = df[col].fillna(df[col].mode()[0])

        return df

    except Exception as e:
        print("Error:", e)

# %%
def handle_duplicate(df):
    try:
        duplicate_count=df.duplicated().sum()
        print(f"duplicated  values : {duplicate_count}")

        if duplicate_count>0:
            df.drop_duplicates(ignore_index=True)

        return df

    except Exception as e:
        print(e)

# %%
def plot_figure(df):
    try:
        print("you are in plot figure")
        test_size=df[df["Date"].dt.year==2022].shape[0]

        plt.figure(
            figsize=(15,6),
            dpi=150
        )
        plt.rcParams["axes.facecolor"] = "pink"
        plt.rcParams["axes.edgecolor"] = "white"

        plt.plot(
            df["Date"][:-test_size],
            df["Price"][:-test_size],
            color="blue",
            lw=2
        )
        plt.plot(
            df["Date"][-test_size:],
            df["Price"][-test_size:],
            color="yellow",
            lw=2
        )
        plt.title("gold price",fontsize=36)
        plt.xlabel("Date",fontsize=12)
        plt.ylabel("Price",fontsize=12)
        plt.legend(
            [
                "Training set",
                "Test set"
            ],
            loc="upper left",
            prop={"size":15}
        )
        plt.grid(color="white")
        plt.show()

    except Exception as e:
        print(f"error  : {e}")

# %%
def build_train_test_dataset(df,test_size,window):
    try:
        train_data=df["Price"][:-test_size].to_numpy().reshape(-1,1)
        x_train=[]
        y_train=[]

        for i in range(window,len(train_data)):
            x_train.append(train_data[i-window:i,0])
            y_train.append(train_data[i,0])


        x_train=np.array(x_train)
        y_train=np.array(y_train)

        print(f"x_train shape :{x_train.shape}")
        print(f"y_train shape :{y_train.shape}")



        test_data=df["Price"][-test_size-window:].to_numpy().reshape(-1,1)
        x_test=[]
        y_test=[]

        for i in range(window,len(test_data)):
            x_test.append(test_data[i-window:i,0])
            y_test.append(test_data[i,0])

        x_test=np.array(x_test)
        y_test=np.array(y_test)


        print(f"x_test shape :{x_test.shape}")
        print(f"y_test shape :{y_test.shape}")


        return x_train,y_train,x_test,y_test

    except Exception as e:
        print(f"error : {e}")

# %%
def get_recent_log_dir():
    try:
        log_path = os.path.join(os.getcwd(), "log","fit")
        log_files = sorted(os.listdir(log_path))
        return os.path.join(log_path, log_files[-1])

    except Exception as e:
        print(f"error : {e}")

def launch_tensorboard():
    try:
        ipython = get_ipython()

        # Load or reload the extension
        try:
            ipython.run_line_magic('reload_ext', 'tensorboard')
        except:
            ipython.run_line_magic('load_ext', 'tensorboard')

        # Get latest log directory
        log_dir = get_recent_log_dir()
        print("Launching TensorBoard at:", log_dir)

        # Start TensorBoard
        ipython.run_line_magic('tensorboard', f'--logdir "{log_dir}"')

    except Exception as e:
        print(f"error : {e}")

# %%
def get_tensorboard_callback():
    try:
        tensor_file_name=datetime.now().strftime("%d_%m_%y__%H_%M_%S")
        log_file= "log"

        log_path=os.path.join(os.getcwd(),log_file,"fit",tensor_file_name)
        dir_name=os.path.dirname(log_path)

        os.makedirs(
            dir_name,
            exist_ok=True
        )

        # return TensorBoard(
        #         log_dir=log_path,
        #         histogram_freq=1
        # )


        return TensorBoard(
            log_dir=log_path,
            histogram_freq=1,
            write_graph=True,
            write_images=True,
            profile_batch=0  # Set to 0 or specific batch index for profiling
        )

    except Exception as e:
        print(f"error : {e}")

# %%
def get_early_stopping_callback():
    try :
        early_stopping_callback=EarlyStopping(
            monitor="val_loss",
            patience=100,
            restore_best_weights=True,
        )
        return  early_stopping_callback

    except Exception as e:
        print(f"error : {e}")

# %%
def build_lstm_model(window):
    try:
        model_units=0
        if window < 100 :
            model_units = 120
        else :
            model_units = window

        input1=Input(shape=(window,1))
        x=LSTM(
            units=model_units,
            return_sequences=True
        )(input1)
        x=Dropout(0.2)(x)
        x=LSTM(
            units=model_units,
            return_sequences=True
        )(x)
        x=Dropout(0.2)(x)
        x=LSTM(
            units=model_units,
            return_sequences=False
        )(x)
        x=Dropout(0.2)(x)
        x=Dense(
            units=int(model_units/2),
            activation="relu"
        )(x)
        x=Dense(
            units=int(model_units/4),
            activation="relu"
        )(x)
        dnn_output=Dense(1)(x)


        model=Model(
            inputs=input1,
            outputs=[dnn_output]
        )
        # model.compile(
        #     loss="mean_squared_error",
        #     optimizer="Nadam"
        # )

        print(f"returning model.")
        model.summary()

        return model


    except Exception as e:
        print(f"build_model error : e")
        return None

# %%
def compile_model(model):
    try:
        model.compile(
            optimizer="adam",
            loss="mae",
            metrics=["mae","mse"]
        )

        return model

    except Exception as e:
        print("error : {e}")

# %%
def run_model(model,x_train,y_train,epochs,window):
    try:
        start_time=datetime.now()
        history=model.fit(
            x_train,
            y_train,
            epochs=epochs,
            batch_size=window*5,
            validation_split=0.2,
            verbose=1,
            callbacks=[
                # get_tensorboard_callback(),
                get_early_stopping_callback()
            ]
        )
        end_time=datetime.now()

        print(f"time taken to run the model : {end_time - start_time}")

        return history

    except Exception as e:
        print(f"error : {e}")

# %%
# def evaluate_history(history):
#     try:
#         history_data = history.history
#         keys = list(history_data.keys())

#         plt.figure(figsize=(10, 6))
#         plt.title("Model Training Metrics")
#         plt.xlabel("Epoch")
#         plt.ylabel("Metric Value")

#         for key in keys:
#             plt.plot(history_data[key], label=key)

#         plt.legend()
#         plt.grid(True)
#         plt.tight_layout()
#         plt.show()

#     except Exception as e:
#         print(f"History evaluation error: {e}")

# %%
def show_history(history,file_dir,window):
    try:
        history_data = history.history
        keys = list(history_data.keys())

        validation_keys=[k for k in keys if k.startswith("val_")]
        training_keys=[k for k in keys if not k.startswith("val_") ]
        file_dir=os.path.join(file_dir,"figures",f"window_{window}_")
        os.makedirs(
            file_dir,
            exist_ok=True
        )

        # for key in keys:
        #     plt.figure(figsize=(5, 3))
        #     plt.xlabel("Epoch")
        #     plt.ylabel(f"{key}")
        #     plt.plot(history_data[key], label=key)
        #     plt.legend()
        #     plt.grid(True)
        #     plt.tight_layout()
        #     plt.show()

        for key1,key2 in zip(training_keys,validation_keys):
            file_name=f"{key1}_{key2}_.png"
            file_path=os.path.join(file_dir,file_name)
            plt.figure(figsize=(5, 3))
            plt.xlabel("Epoch")
            # plt.ylabel(f"{key}")
            plt.plot(history_data[key1], label=key1)
            plt.plot(history_data[key2], label=key2)
            plt.legend()
            plt.grid(True)
            plt.tight_layout()
            plt.savefig(file_path)
            plt.show()


    except Exception as e:
        print(f"History evaluation error: {e}")

# %%
#

# %%
def save_history_csv(history, file_path):
    try:
        df = pd.DataFrame(history.history)
        df.to_csv(file_path, index=False)

        print(f"History saved as CSV at {file_path}")
    except Exception as e:
        print(f"Error saving history as CSV: {e}")

# %%
def history_details(history):
    try:
        file_name=datetime.now().strftime("history%d_%m_%y__%Hh_%Mm_%Ss")+".csv"
        file_path=os.path.join(os.getcwd(),"history",file_name)
        file_dir=os.path.dirname(file_path)
        os.makedirs(
            file_dir,
            exist_ok=True
        )

        save_history_csv(history,file_path)
        show_history(history)


    except Exception as e:
        print(f"History evaluation error: {e}")

# %%
def history_details1(history,file_dir,window):
    try:
        file_name=f"history_{window}_.csv"
        file_path=os.path.join(os.getcwd(),"history",file_dir,file_name)
        file_dir=os.path.dirname(file_path)

        os.makedirs(
            file_dir,
            exist_ok=True
        )

        save_history_csv(history,file_path)
        show_history(history,file_dir,window)


    except Exception as e:
        print(f"History evaluation error: {e}")

# %%
def evaluate_model():
    try:
        # evaluate_history()
        launch_tensorboard()

    except Exception as e:
        print(f"error : {e}")

# %%
def run_training():
    try:
        input_file_path=locate_input_file()
        print(input_file_path)


        df=get_input_data(input_file_path)
        print_details(df)

        unwanted_columns=['Open', 'High', 'Low', 'Vol.', 'Change %']
        df=remove_unwanted_columns(df,unwanted_columns)
        print_details(df)

        df=clean_data(df)
        print(df.head())
        print(df.tail())


        df=handle_missing(df)

        df=handle_duplicate(df)

        plot_figure(df)


        test_size=df[df["Date"].dt.year==2022].shape[0]
        window=60

        print(test_size,window)


        x_train,y_train,x_test,y_test=build_train_test_dataset(
            df,
            test_size,
            window
        )

        model=build_lstm_model(window)

        model=compile_model(model)

        model_file_name=f"model_{window}_.keras"
        model.save(model_file_name)

        epochs=50

        history=run_model(
            model,
            x_train,
            y_train,
            epochs
        )

        history_details(history)

        evaluate_model()




    except Exception as e:
        print(f"error : {e}")

# %%
# run_training()

# %%
def test_training():
    try:
        input_file_path=locate_input_file()
        print(input_file_path)


        df=get_input_data(input_file_path)
        print_details(df)

        unwanted_columns=['Open', 'High', 'Low', 'Vol.', 'Change %']
        df=remove_unwanted_columns(df,unwanted_columns)
        print_details(df)

        df=clean_data(df)
        print(df.head())
        print(df.tail())


        df=handle_missing(df)

        df=handle_duplicate(df)

        plot_figure(df)


        test_size=df[df["Date"].dt.year==2022].shape[0]
        window=60

        print(test_size,window)


        x_train,y_train,x_test,y_test=build_train_test_dataset(
            df,
            test_size,
            window
        )

        # model=build_lstm_model(window)

        # model=compile_model(model)

        # model_file_name=f"model_{window}_.h5"
        # model.save(model_file_name)

        # epochs=50

        # history=run_model(
        #     model,
        #     x_train,
        #     y_train,
        #     epochs
        # )

        # history_details(history)

        # evaluate_model()




    except Exception as e:
        print(f"error : {e}")

# %%
def build_model_pipeline():
    try:

        dir_name=datetime.now().strftime("%d_%m_%y__%Hh_%Mm_%Ss")

        input_file_path = locate_input_file()
        print(input_file_path)

        df = get_input_data(input_file_path)
        # print_details(df)

        unwanted_columns = ['Open', 'High', 'Low', 'Vol.', 'Change %']
        df = remove_unwanted_columns(df, unwanted_columns)
        print_details(df)

        df = clean_data(df,dir_name)
        print(f"df type : {type(df)}")
        print(df.head())
        print(df.tail())

        df = handle_missing(df)
        df = handle_duplicate(df)

        plot_figure(df)

        test_size = df[df["Date"].dt.year == 2022].shape[0]

        windows = [5, 20, 60, 120, 240]
        epochs = 5
        testing_data = []
        real_data = []

        dir_name=datetime.now().strftime("%d_%m_%y__%Hh_%Mm_%Ss")
        history_file_dir=f"history_{dir_name}__epochs_{epochs}"
        model_file_dir=f"model_{dir_name}__epochs_{epochs}"

        for window in windows:
            x_train, y_train, x_test, y_test = build_train_test_dataset(
                df,
                test_size,
                window
            )
            testing_data.append(x_test[0])
            real_data.append(y_test[0])

            model = build_lstm_model(window)
            model = compile_model(model)

            history = run_model(
                model,
                x_train,
                y_train,
                epochs=epochs,
                window=window
            )

            history_details1(history,history_file_dir,window)

            model_file_dir=os.path.join(os.getcwd(),"models",model_file_dir)
            model_file_name = f"model_{window}_.keras"
            model_file_path=os.path.join(model_file_dir,model_file_name)
            os.makedirs(
                model_file_dir,
                exist_ok=True
            )

            model.save(model_file_path)

        # for data in testing_data:
        #     print(data)

        # for data in real_data:
        #     print(data)

    except Exception as e:
        print(f"error: {e}")

# %%
build_model_pipeline()
# Out:
# e:\data_science_play_ground\gold_price_prediction\gold_price_2013_2023.csv
# all unwanted columns can be removed.
# shape of df : (2583, 2)
#
# columns of df : Index(['Date', 'Price'], dtype='object')
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2583 non-null   object
#  1   Price   2583 non-null   object
# dtypes: object(2)
# memory usage: 40.5+ KB
# information about df :
# None
#
#
# description about df :
#               Date     Price
# count         2583      2583
# unique        2583      2072
# top     12/30/2022  1,294.30
# freq             1         5
#
#
# head of df :
#          Date     Price
# 0  12/30/2022  1,826.20
# 1  12/29/2022  1,826.00
# 2  12/28/2022  1,815.80
# 3  12/27/2022  1,823.10
# 4  12/26/2022  1,809.70
#
#
# tail of df :
#             Date     Price
# 2578  01/08/2013  1,663.20
# 2579  01/07/2013  1,647.20
# 2580  01/04/2013  1,649.90
# 2581  01/03/2013  1,675.60
# 2582  01/02/2013  1,689.90
#
#
# df type : <class 'pandas.core.frame.DataFrame'>
#            Date     Price
# 2582 2013-01-02  0.634715
# 2581 2013-01-03  0.620539
# 2580 2013-01-04  0.595063
# 2579 2013-01-07  0.592387
# 2578 2013-01-08  0.608247
#         Date     Price
# 4 2022-12-26  0.753469
# 3 2022-12-27  0.766753
# 2 2022-12-28  0.759516
# 1 2022-12-29  0.769627
# 0 2022-12-30  0.769826
# Column-wise missing values:
# Date     0
# Price    0
# dtype: int64
#
# Total missing values: 0
#
# Numerical columns: ['Price']
# Categorical columns: []
# duplicated  values : 0
# you are in plot figure
# x_train shape :(2318, 5)
# y_train shape :(2318,)
# x_test shape :(260, 5)
# y_test shape :(260,)
# returning model.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 5, 120)         │        58,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 120)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 5, 120)         │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 120)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 120)            │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 60)             │         7,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 299,041 (1.14 MB)
#  Trainable params: 299,041 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0068 - val_loss: 0.0387 - val_mae: 0.0387 - val_mse: 0.0025
# Epoch 2/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0210 - mae: 0.0210 - mse: 8.1045e-04 - val_loss: 0.0553 - val_mae: 0.0553 - val_mse: 0.0039
# Epoch 3/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0211 - mae: 0.0211 - mse: 8.1864e-04 - val_loss: 0.0363 - val_mae: 0.0363 - val_mse: 0.0019
# Epoch 4/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0197 - mae: 0.0197 - mse: 7.1560e-04 - val_loss: 0.0375 - val_mae: 0.0375 - val_mse: 0.0022
# Epoch 5/5
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0226 - mae: 0.0226 - mse: 8.9623e-04 - val_loss: 0.0950 - val_mae: 0.0950 - val_mse: 0.0100
# time taken to run the model : 0:00:06.211751
# History saved as CSV at e:\data_science_play_ground\gold_price_prediction\history\history_07_09_25__12h_27m_43s__epochs_5\history_5_.csv
# x_train shape :(2303, 20)
# y_train shape :(2303,)
# x_test shape :(260, 20)
# y_test shape :(260,)
# returning model.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 20, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 20, 120)        │        58,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 20, 120)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 20, 120)        │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 20, 120)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 120)            │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 60)             │         7,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 299,041 (1.14 MB)
#  Trainable params: 299,041 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.1008 - mae: 0.1008 - mse: 0.0179 - val_loss: 0.1673 - val_mae: 0.1673 - val_mse: 0.0302
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0441 - mae: 0.0441 - mse: 0.0035 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0154
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0314 - mae: 0.0314 - mse: 0.0018 - val_loss: 0.0576 - val_mae: 0.0576 - val_mse: 0.0047
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0282 - mae: 0.0282 - mse: 0.0015 - val_loss: 0.0366 - val_mae: 0.0366 - val_mse: 0.0023
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - mae: 0.0278 - mse: 0.0014 - val_loss: 0.0540 - val_mae: 0.0540 - val_mse: 0.0041
# time taken to run the model : 0:00:07.378786
# History saved as CSV at e:\data_science_play_ground\gold_price_prediction\history\history_07_09_25__12h_27m_43s__epochs_5\history_20_.csv
# x_train shape :(2263, 60)
# y_train shape :(2263,)
# x_test shape :(260, 60)
# y_test shape :(260,)
# returning model.
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 60, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 60, 120)        │        58,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 60, 120)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 60, 120)        │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 60, 120)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 120)            │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 60)             │         7,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 299,041 (1.14 MB)
#  Trainable params: 299,041 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 402ms/step - loss: 0.0930 - mae: 0.0930 - mse: 0.0165 - val_loss: 0.2195 - val_mae: 0.2195 - val_mse: 0.0504
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - loss: 0.0412 - mae: 0.0412 - mse: 0.0028 - val_loss: 0.1318 - val_mae: 0.1318 - val_mse: 0.0193
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - loss: 0.0314 - mae: 0.0314 - mse: 0.0017 - val_loss: 0.0648 - val_mae: 0.0648 - val_mse: 0.0058
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - loss: 0.0296 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0413 - val_mae: 0.0413 - val_mse: 0.0027
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - loss: 0.0288 - mae: 0.0288 - mse: 0.0015 - val_loss: 0.0777 - val_mae: 0.0777 - val_mse: 0.0076
# time taken to run the model : 0:00:14.469319
# History saved as CSV at e:\data_science_play_ground\gold_price_prediction\history\history_07_09_25__12h_27m_43s__epochs_5\history_60_.csv
# x_train shape :(2203, 120)
# y_train shape :(2203,)
# x_test shape :(260, 120)
# y_test shape :(260,)
# returning model.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 120, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 120, 120)       │        58,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 120, 120)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 120, 120)       │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 120, 120)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 120)            │       115,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 60)             │         7,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 299,041 (1.14 MB)
#  Trainable params: 299,041 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.1484 - mae: 0.1484 - mse: 0.0329 - val_loss: 0.1586 - val_mae: 0.1586 - val_mse: 0.0276
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 946ms/step - loss: 0.0907 - mae: 0.0907 - mse: 0.0122 - val_loss: 0.3586 - val_mae: 0.3586 - val_mse: 0.1315
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 935ms/step - loss: 0.0738 - mae: 0.0738 - mse: 0.0094 - val_loss: 0.3343 - val_mae: 0.3343 - val_mse: 0.1146
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 946ms/step - loss: 0.0517 - mae: 0.0517 - mse: 0.0049 - val_loss: 0.1212 - val_mae: 0.1212 - val_mse: 0.0170
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 954ms/step - loss: 0.0551 - mae: 0.0551 - mse: 0.0044 - val_loss: 0.2477 - val_mae: 0.2477 - val_mse: 0.0638
# time taken to run the model : 0:00:16.810960
# History saved as CSV at e:\data_science_play_ground\gold_price_prediction\history\history_07_09_25__12h_27m_43s__epochs_5\history_120_.csv
# x_train shape :(2083, 240)
# y_train shape :(2083,)
# x_test shape :(260, 240)
# y_test shape :(260,)
# returning model.
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 240, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_12 (LSTM)                  │ (None, 240, 240)       │       232,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 240, 240)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 240, 240)       │       461,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 240, 240)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 240)            │       461,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 240)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 120)            │        28,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 60)             │         7,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            61 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,192,081 (4.55 MB)
#  Trainable params: 1,192,081 (4.55 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - loss: 0.2259 - mae: 0.2259 - mse: 0.0664 - val_loss: 0.2665 - val_mae: 0.2665 - val_mse: 0.0738
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 5s/step - loss: 0.1756 - mae: 0.1756 - mse: 0.0754 - val_loss: 0.0746 - val_mae: 0.0746 - val_mse: 0.0072
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - loss: 0.0986 - mae: 0.0986 - mse: 0.0125 - val_loss: 0.5412 - val_mae: 0.5412 - val_mse: 0.2965
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - loss: 0.1397 - mae: 0.1397 - mse: 0.0290 - val_loss: 0.5592 - val_mae: 0.5592 - val_mse: 0.3164
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - loss: 0.1305 - mae: 0.1305 - mse: 0.0267 - val_loss: 0.4498 - val_mae: 0.4498 - val_mse: 0.2057
# time taken to run the model : 0:01:09.286580
# History saved as CSV at e:\data_science_play_ground\gold_price_prediction\history\history_07_09_25__12h_27m_43s__epochs_5\history_240_.csv

# %%
# windows=[5,20,60,120,240]
# epochs=10
# testing_data=[]
# real_data=[]

# for window in windows:
#     x_train,y_train,x_test,y_test=build_train_test_dataset(
#         df,
#         test_size,
#         window
#     )
#     testing_data.append(x_test[0])
#     real_data.append(y_test[0])

#     model=build_model(window)
#     model=compile_model(model)

#     history=run_model(
#         model,
#         x_train,
#         y_train,
#         epochs=10
#     )

#     model_file_name=f"model_{window}_.h5"
#     model.save(model_file_name)


# for data in testing_data:
#     print(data)

# for data in real_data:
#     print(data)

# %%
        #  df['Close'] ──► [LSTM: window=6] ─┐
        #                    prediction_6   │
        #  df['Close'] ──► [LSTM: window=20] ─┐
        #                    prediction_20   │
        #  df['Close'] ──► [LSTM: window=60] ─┐
        #                    prediction_60   │
        #  df['Close'] ──► [LSTM: window=120] ─┐
        #                    prediction_120   │──► [Sequential Meta Model] ─► Final Output
        #  df['Close'] ──► [LSTM: window=240] ─┘
        #                    prediction_240

# %%
# windows = [5, 20, 60, 120, 240]
# meta_inputs = []
# real_outputs = None  # will be set once

# for window in windows:
#     model = load_model(f"lstm_window_{window}.h5")
#     x_train, y_train, x_test, y_test = build_train_test_dataset(df, test_size, window)

#     preds = model.predict(x_test)
#     meta_inputs.append(preds.reshape(-1, 1))  # reshape to column

#     if real_outputs is None:
#         real_outputs = y_test  # assuming all y_test are aligned

# # Stack predictions horizontally
# X_meta = np.hstack(meta_inputs)  # shape: (samples, 5)
# y_meta = real_outputs

# %%
# def build_meta_model(input_dim=5):
#     model = Sequential()
#     model.add(Dense(64, activation='relu', input_shape=(input_dim,)))
#     model.add(Dropout(0.2))
#     model.add(Dense(32, activation='relu'))
#     model.add(Dense(1))  # Predict final price
#     model.compile(optimizer='adam', loss='mse')
#     return model

# meta_model = build_meta_model()
# meta_model.fit(X_meta, y_meta, epochs=10, batch_size=32)

# # Save the meta model
# meta_model.save("meta_model.h5")

# %%
# # Load LSTM models and meta-model
# lstm_models = [load_model(f"lstm_window_{w}.h5") for w in windows]
# meta_model = load_model("meta_model.h5")

# # Assume x_test from each LSTM model is available
# meta_input = []

# for i, window in enumerate(windows):
#     _, _, x_test, _ = build_train_test_dataset(df, test_size, window)
#     preds = lstm_models[i].predict(x_test)
#     meta_input.append(preds.reshape(-1, 1))

# meta_input = np.hstack(meta_input)  # shape: (samples, 5)

# final_predictions = meta_model.predict(meta_input)

# print(final_predictions[:5])

# %%
# import shutil
# from google.colab import files

# # Create a zip of the history folder
# shutil.make_archive("/content/history", 'zip', "/content/history")

# # Download the zipped folder
# files.download("/content/history.zip")
